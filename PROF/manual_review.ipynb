# %%
from pathlib import Path
import json
import pandas as pd
from IPython.display import display, HTML

BASE_DIR = Path(".").resolve()
MAPPINGS_DIR = BASE_DIR / "mappings" / "mappings_isx"

# %%
rows = []

for fp in sorted(MAPPINGS_DIR.glob("*.json")):
    firm_id = fp.stem
    data = json.loads(fp.read_text(encoding="utf-8"))

    for v in data.get("variables", []):
        if v.get("needs_manual_review", False):
            final_choice = v.get("final_choice", [])
            # make final_choice readable
            final_str = "; ".join([f"{x['sheet_name']}::{x['row_label']}" for x in final_choice]) if final_choice else ""
            rows.append({
                "firm_id": firm_id,
                "variable": v.get("variable", ""),
                "notes": v.get("notes", ""),
                "final_choice": final_str,
                "num_candidates": len(v.get("candidates", [])),
            })

if len(rows) == 0:
    print("No manual reviews needed. All mappings have been reviewed and finalized.")
else:
    df_review = pd.DataFrame(rows).sort_values(["firm_id", "variable"]).reset_index(drop=True)

    print(f"Manual review needed for {len(df_review)} firm-variable mappings across {df_review['firm_id'].nunique() if len(df_review) else 0} firms.")
    display(HTML(f"""
    <div style="max-height: 450px; overflow-y: auto; border: 1px solid #ddd; padding: 6px;">
    {df_review.to_html(index=False)}
    </div>
    """))
# Out:
# Manual review needed for 3 firm-variable mappings across 3 firms.
#     <div style="max-height: 450px; overflow-y: auto; border: 1px solid #ddd; padding: 6px;">
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>firm_id</th>
#       <th>variable</th>
#       <th>notes</th>
#       <th>final_choice</th>
#       <th>num_candidates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ICEAIR.IC</td>
#       <td>REVT</td>
#       <td>Candidate list misses the clear total top-line row. 'Operating Income' appears above operating expenses and equals the aggregate of operating revenues, so it is the best available revenue line. Manual review because the label is unconventional and could be interpreted as revenue subtotal rather than standard 'Revenue'. | Escape-hatch used (final_choice outside candidate list): [Income Statement] Operating Income</td>
#       <td>Income Statement::Operating Income</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <td>SJOVA.IC</td>
#       <td>COGS</td>
#       <td>No candidates were provided. For an insurer, direct service/claims costs are the closest COGS analogue. 'Insurance Service Expenses - IFRS 17' fits IFRS 17 years, while 'Net Claims' appears to be the legacy direct insurance cost line for 2021. Manual review recommended because insurance statements do not present classic COGS terminology.</td>
#       <td>Income Statement::Insurance Service Expenses - IFRS 17; Income Statement::Net Claims</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>SKAGI.IC</td>
#       <td>REVT</td>
#       <td>Selected outside candidate list because none of the provided candidates clearly match the main total revenue across years. 'Heildartekjur' appears to be the broad total revenue/top-line line, while the duplicated 'Insurance revenue' rows appear inconsistent due to reporting changes. | Escape-hatch used (final_choice outside candidate list): [Income Statement] Heildartekjur</td>
#       <td>Income Statement::Heildartekjur</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
#     </div>

# %%
rows = []

for fp in sorted(MAPPINGS_DIR.glob("*.json")):
    firm_id = fp.stem
    data = json.loads(fp.read_text(encoding="utf-8"))

    for v in data.get("variables", []):
        if v.get("needs_manual_review", False):
            final_choice = v.get("final_choice", [])
            # make final_choice readable
            final_str = "; ".join([f"{x['sheet_name']}::{x['row_label']}" for x in final_choice]) if final_choice else ""
            rows.append({
                "firm_id": firm_id,
                "variable": v.get("variable", ""),
                "notes": v.get("notes", ""),
                "final_choice": final_str,
                "num_candidates": len(v.get("candidates", [])),
            })

if len(rows) == 0:
    print("No manual reviews needed. All mappings have been reviewed and finalized.")
else:
    df_review = pd.DataFrame(rows).sort_values(["firm_id", "variable"]).reset_index(drop=True)

    print(f"Manual review needed for {len(df_review)} firm-variable mappings across {df_review['firm_id'].nunique() if len(df_review) else 0} firms.")
    display(HTML(f"""
    <div style="max-height: 450px; overflow-y: auto; border: 1px solid #ddd; padding: 6px;">
    {df_review.to_html(index=False)}
    </div>
    """))
# Out:
# Manual review needed for 3 firm-variable mappings across 3 firms.
#     <div style="max-height: 450px; overflow-y: auto; border: 1px solid #ddd; padding: 6px;">
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>firm_id</th>
#       <th>variable</th>
#       <th>notes</th>
#       <th>final_choice</th>
#       <th>num_candidates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>ICEAIR.IC</td>
#       <td>REVT</td>
#       <td>Candidate list misses the clear total top-line row. 'Operating Income' appears above operating expenses and equals the aggregate of operating revenues, so it is the best available revenue line. Manual review because the label is unconventional and could be interpreted as revenue subtotal rather than standard 'Revenue'. | Escape-hatch used (final_choice outside candidate list): [Income Statement] Operating Income</td>
#       <td>Income Statement::Operating Income</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <td>SJOVA.IC</td>
#       <td>COGS</td>
#       <td>No candidates were provided. For an insurer, direct service/claims costs are the closest COGS analogue. 'Insurance Service Expenses - IFRS 17' fits IFRS 17 years, while 'Net Claims' appears to be the legacy direct insurance cost line for 2021. Manual review recommended because insurance statements do not present classic COGS terminology.</td>
#       <td>Income Statement::Insurance Service Expenses - IFRS 17; Income Statement::Net Claims</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>SKAGI.IC</td>
#       <td>REVT</td>
#       <td>Selected outside candidate list because none of the provided candidates clearly match the main total revenue across years. 'Heildartekjur' appears to be the broad total revenue/top-line line, while the duplicated 'Insurance revenue' rows appear inconsistent due to reporting changes. | Escape-hatch used (final_choice outside candidate list): [Income Statement] Heildartekjur</td>
#       <td>Income Statement::Heildartekjur</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
